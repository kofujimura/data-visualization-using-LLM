# %% [markdown]
# <a href="https://colab.research.google.com/github/kofujimura/foods-similarity-using-LLM/blob/main/LLM%E3%82%92%E6%B4%BB%E7%94%A8%E3%81%97%E3%81%9F%E9%A3%9F%E5%93%81%E9%96%93%E3%81%AE%E9%A1%9E%E4%BC%BC%E5%BA%A6%E3%81%AE%E5%8F%AF%E8%A6%96%E5%8C%96.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LLMを活用した食品間の類似度の可視化
# 生成AIのembedingモデルを活用して114種類の食品間の類似度を算出します。Google Colaboratoryでの実行を前提として、OPENAI_API_KEYの値をColaboratoryのuserdataに設定することが必要です。

# %% [markdown]
# ## ライブラリのインストールとAPIキー設定
#
# ### Subtask:
# 必要なPythonライブラリ（openai, pandas, numpy, openpyxl）をインストールし、OpenAI APIキーを設定します。

# %%
# ===============================
# 1. 必要ライブラリのインストール
# ===============================
# !pip install -q openai pandas numpy openpyxl

from openai import OpenAI
import pandas as pd
import numpy as np
from numpy.linalg import norm

# ===============================
# 2. APIキー設定（重要）
# ===============================
# 左側の「鍵マーク」から環境変数 OPENAI_API_KEY を追加する
# ここに直接書いてもOK（ただし公開しないこと）
from google.colab import userdata
client = OpenAI(api_key=userdata.get('OPENAI_API_KEY'))

# %% [markdown]
# ## データファイルの読み込み
#
# ### Subtask:
# 提供されたパスから[`foods-text.xlsx`](https://docs.google.com/spreadsheets/d/18IVgqL7n7gk1TIRpAi8vcOJDdvYKeDez/edit?usp=sharing&ouid=109677197366385298416&rtpof=true&sd=true)ファイルをPandas DataFrameとして読み込みます。

# %%
file_path = "/content/foods-text.xlsx"
df = pd.read_excel(file_path)
df.head()
# Out:
#        食品名                                             実際の調理法  \
# 0   鶏のから揚げ  一口大に切った鶏もも肉にショウガ汁、すりおろしニンニク、醤油、酒などで下味をつけて揉み、片栗...
# 1  アイスクリーム             牛乳や生クリーム、砂糖、卵黄などを混ぜ合わせ、攪拌しながら凍らせて作る冷菓。
# 2  フライドポテト        じゃがいもを食べやすい大きさに切って油で揚げる。揚げたてに塩を振って食べるのが一般的。
# 3    オムライス                    ケチャップで味付けしたチキンライスを薄焼き卵で包んで作る洋食。
# 4       豚汁  豚肉と根菜類を具に味噌で仕立てた汁物。豚肉、大根、人参、ごぼう、こんにゃく等を炒めてから出汁...
#
#                                                 主な材料
# 0  鶏肉（もも肉またはむね肉）、醤油、みりん、酒、にんにく、生姜、塩、胡椒、片栗粉または小麦粉、揚げ油
# 1                 牛乳、生クリーム、砂糖、卵黄、バニラエッセンス（バニラビーンズ）など
# 2                                       じゃがいも、サラダ油、塩
# 3                      鶏肉、玉ねぎ、ご飯、卵、トマトケチャップ、バター、塩、胡椒
# 4                    豚肉、大根、人参、ごぼう、こんにゃく、里芋、長ネギ、味噌、出汁

# %% [markdown]
# ## Embedding用テキストの整形
#
# ### Subtask:
# DataFrameの各行から「食品名」「調理法」「主な材料」を結合し、Embedding生成用のテキストリストを作成します。

# %%
# ===============================
# 4. Embedding 用のテキスト整形
# ===============================
def build_text(row):
    return (
        f"食品名：{row['食品名']}。"
        f"調理法：{row['実際の調理法']}。"
        f"主な材料：{row['主な材料']}。"
    )

texts = df.apply(build_text, axis=1).tolist()

# %% [markdown]
# ## Embeddingの生成
#
# ### Subtask:
# 整形したテキストリストを使用してOpenAIの`text-embedding-3-large`モデルでEmbeddingを生成します。この処理には時間がかかる場合があります。

# %%
print("Embedding を生成中...（1〜2分かかる場合あり）")

response = client.embeddings.create(
    model="text-embedding-3-large",
    input=texts
)

embeddings = np.array([item.embedding for item in response.data])
embeddings.shape

# %% [markdown]
# ## コサイン類似度関数の定義
#
# ### Subtask:
# 2つのベクトル間のコサイン類似度を計算する`cosine_sim`関数を定義します。

# %%
# ===============================
# 6. コサイン類似度の計算関数
# ===============================
def cosine_sim(a, b):
    return float(np.dot(a, b) / (norm(a) * norm(b)))

# %% [markdown]
# ## 類似料理の検索と表示
#
# ### Subtask:
# 指定されたインデックスの料理に類似する料理を、生成したEmbeddingとコサイン類似度関数を用いて検索し、上位5件を表示します。

# %%
# ===============================
# 7. 任意の料理に似た料理を上位5件出す
# ===============================
def similar_food(index, top_k=5):
    target_vec = embeddings[index]
    sims = []

    for i, vec in enumerate(embeddings):
        if i == index:
            continue
        sim = cosine_sim(target_vec, vec)
        sims.append((i, sim))

    sims_sorted = sorted(sims, key=lambda x: x[1], reverse=True)

    print(f"=== 「{df.iloc[index]['食品名']}」に似ている料理 TOP {top_k} ===")
    for idx, sim in sims_sorted[:top_k]:
        print(f"類似度: {sim:.3f} | {df.iloc[idx]['食品名']}")

# 例：0番目の料理に似た料理
similar_food(0)
# Out:
# === 「鶏のから揚げ」に似ている料理 TOP 5 ===
# 類似度: 0.642 | フライドチキン
# 類似度: 0.577 | しょうが焼き
# 類似度: 0.575 | フライドポテト
# 類似度: 0.571 | 肉じゃが
# 類似度: 0.571 | ハンバーグ

# %% [markdown]
# ## D3.js用データの準備: ノードの生成
#
# ### Subtask:
# `df` DataFrameからD3.jsグラフのノードリストを作成します。各ノードには、食品のID（インデックス）と、`df`の「食品名」カラムからの食品名を含めます。ノードに色をつけるために、k-mean法で各食品ベクトルをクラスタリングします。第４回の授業と同様にkの値を15にしてみましょう。

# %% [markdown]
# ## Modify nodes generation
#
# ### Subtask:
# 既存のノード生成コードを修正し、抽出したグループマッピングを使用して各ノードに適切な`group`属性を設定します。

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
k_means=KMeans(n_clusters=15)

# K-meansクラスタリングの実行し、結果をdfに追加
df["kmeans"]=k_means.fit_predict(embeddings)

# クラスタリング結果でソートして表示
df.sort_values(by="kmeans")[["kmeans"]]
# Out:
#      kmeans
# 98        0
# 101       0
# 12        1
# 11        1
# 20        1
# ..      ...
# 51       14
# 21       14
# 50       14
# 84       14
# 69       14
#
# [114 rows x 1 columns]

# %%
nodes = []
for i, food_name in enumerate(df['食品名']):
    group_id = df['kmeans'][i]
    nodes.append({
        'id': food_name,
        'group': group_id
    })

print(f"Generated {len(nodes)} nodes for the D3.js graph with group information.")
# Out:
# Generated 114 nodes for the D3.js graph with group information.

# %% [markdown]
# ## 全食品ペア間の類似度計算
#
# ### Subtask:
# すべての食品ペアについて、コサイン類似度を計算し、データ構造に格納します。

# %%
similarity_scores = []
n_foods = len(embeddings)

for i in range(n_foods):
    for j in range(i + 1, n_foods):
        sim = cosine_sim(embeddings[i], embeddings[j])
        similarity_scores.append((i, j, sim))

print(f"Calculated {len(similarity_scores)} similarity scores for all unique food pairs.")
# Out:
# Calculated 6441 similarity scores for all unique food pairs.

# %% [markdown]
# ## D3.js用データの準備: エッジの抽出
#
# ### Subtask:
# 各食品について、上位10件の類似する食品をエッジとして抽出し、後続のD3.jsノード・エッジデータ生成に備えます。

# %% [markdown]
# ### Subtask:
# 各食品のエッジ数を計算し、その分布をヒストグラムで可視化します。

# %% [markdown]
# ## エッジ抽出ロジックの修正 (Top Kの削減)
#
# ### Subtask:
# 各食品について、類似する食品を上位3件に絞り、Setを使った重複チェックで孤立ノードが発生しないようにエッジを抽出します。

# %%
import collections

edges_raw = collections.defaultdict(list)

for i, j, sim in similarity_scores:
    edges_raw[i].append({'target_id': j, 'value': sim})
    edges_raw[j].append({'target_id': i, 'value': sim})

edges = []
added_edges = set()

for source_id, connections in edges_raw.items():
    # Sort connections by similarity value in descending order and take the top 3
    top_connections = sorted(connections, key=lambda x: x['value'], reverse=True)[:3]
    for conn in top_connections:
        target_id = conn['target_id']
        # Create normalized edge key
        edge_key = (source_id, target_id) if source_id < target_id else (target_id, source_id)
        
        # Add edge only if not already added
        if edge_key not in added_edges:
            added_edges.add(edge_key)
            edges.append({
                'source': df.iloc[source_id]['食品名'],
                'target': df.iloc[target_id]['食品名'],
                'value': conn['value'] * 10  # 類似度を10倍にスケール
            })

print(f"Generated {len(edges)} unique edges for the D3.js graph.")

# %% [markdown]
# ## D3.js用データの最終出力
#
# ### Subtask:
# 生成されたノードリストとエッジリストを結合し、D3.jsが消費できる単一のJSONオブジェクト（`{"nodes": [...], "links": [...]}`の形式）として出力します。

# %%
import json

# Ensure 'group' values in nodes are standard Python ints
cleaned_nodes = []
for node in nodes:
    cleaned_node = node.copy()
    cleaned_node['group'] = int(cleaned_node['group'])
    cleaned_nodes.append(cleaned_node)

d3_data = {
    "nodes": cleaned_nodes,
    "links": edges
}

# JSON形式で出力
json_output = json.dumps(d3_data, indent=2, ensure_ascii=False)

print("D3.js compatible JSON data regenerated with scaled link values.")
print(json_output)
# Out:
# D3.js compatible JSON data regenerated with scaled link values.
# {
#   "nodes": [
#     {
#       "id": "鶏のから揚げ",
#       "group": 8
#     },
#     {
#       "id": "アイスクリーム",
#       "group": 6
#     },
#     {
#       "id": "フライドポテト",
#       "group": 8
#     },
#     {
#       "id": "オムライス",
#       "group": 8
#     },
#     {
#       "id": "豚汁",
#       "group": 11
#     },
#     {
#       "id": "餃子",
#       "group": 13
#     },
#     {
#       "id": "ご飯",
#       "group": 3
#     },
#     {
#       "id": "ハンバーグ",
#       "group": 2
#     },
#     {
#       "id": "ローストビーフ",
#       "group": 7
#     },
#     {
#       "id": "にぎり寿司",
#       "group": 3
#     },
#     {
#       "id": "味噌汁",
#       "group": 11
#     },
#     {
#       "id": "ビーフシチュー",
#       "group": 1
#     },
#     {
#       "id": "サーロインステーキ",
#       "group": 1
#     },
#     {
#       "id": "ハンバーガ",
#       "group": 2
#     },
#     {
#       "id": "ネギトロ丼",
#       "group": 10
#     },
#     {
#       "id": "プリン",
#       "group": 6
#     },
#     {
#       "id": "海老の天ぷら",
#       "group": 3
#     },
#     {
#       "id": "肉じゃが",
#       "group": 1
#     },
#     {
#       "id": "フライドチキン",
#       "group": 8
#     },
#     {
#       "id": "ミートスパゲティ",
#       "group": 1
#     },
#     {
#       "id": "しょうが焼き",
#       "group": 1
#     },
#     {
#       "id": "マカロニグラタン",
#       "group": 14
#     },
#     {
#       "id": "シュークリーム",
#       "group": 6
#     },
#     {
#       "id": "エビフライ",
#       "group": 8
#     },
#     {
#       "id": "ドリア",
#       "group": 8
#     },
#     {
#       "id": "チョコレートケーキ",
#       "group": 6
#     },
#     {
#       "id": "マグロ・トロの刺身",
#       "group": 12
#     },
#     {
#       "id": "ビビンバ",
#       "group": 5
#     },
#     {
#       "id": "ロールキャベツ",
#       "group": 11
#     },
#     {
#       "id": "タピオカ",
#       "group": 6
#     },
#     {
#       "id": "味噌ラーメン",
#       "group": 7
#     },
#     {
#       "id": "ミックスピザ",
#       "group": 2
#     },
#     {
#       "id": "チーズケーキ",
#       "group": 6
#     },
#     {
#       "id": "ショートケーキ",
#       "group": 6
#     },
#     {
#       "id": "ビーフカレー",
#       "group": 9
#     },
#     {
#       "id": "タラコスパゲティ",
#       "group": 8
#     },
#     {
#       "id": "マグロの刺身",
#       "group": 12
#     },
#     {
#       "id": "しょうゆラーメン",
#       "group": 7
#     },
#     {
#       "id": "リゾット",
#       "group": 5
#     },
#     {
#       "id": "ホットケーキ",
#       "group": 6
#     },
#     {
#       "id": "ラザニア",
#       "group": 7
#     },
#     {
#       "id": "ヒレステーキ",
#       "group": 1
#     },
#     {
#       "id": "カルボナーラ",
#       "group": 7
#     },
#     {
#       "id": "きつねうどん",
#       "group": 9
#     },
#     {
#       "id": "鍋焼きうどん",
#       "group": 9
#     },
#     {
#       "id": "春巻き",
#       "group": 13
#     },
#     {
#       "id": "チンジャオロース",
#       "group": 1
#     },
#     {
#       "id": "チキンカレー",
#       "group": 9
#     },
#     {
#       "id": "エビチリ",
#       "group": 7
#     },
#     {
#       "id": "冷しそうめん",
#       "group": 5
#     },
#     {
#       "id": "ポテトサラダ",
#       "group": 14
#     },
#     {
#       "id": "シーフードサラダ",
#       "group": 14
#     },
#     {
#       "id": "親子丼",
#       "group": 4
#     },
#     {
#       "id": "塩ラーメン",
#       "group": 7
#     },
#     {
#       "id": "ホットドック",
#       "group": 2
#     },
#     {
#       "id": "牛丼",
#       "group": 4
#     },
#     {
#       "id": "タマゴサンド",
#       "group": 2
#     },
#     {
#       "id": "五目焼きそば",
#       "group": 13
#     },
#     {
#       "id": "豚の角煮",
#       "group": 7
#     },
#     {
#       "id": "たいやき",
#       "group": 8
#     },
#     {
#       "id": "いくら丼",
#       "group": 3
#     },
#     {
#       "id": "コロッケ",
#       "group": 1
#     },
#     {
#       "id": "野菜炒め",
#       "group": 11
#     },
#     {
#       "id": "モンブラン",
#       "group": 6
#     },
#     {
#       "id": "カレーうどん",
#       "group": 9
#     },
#     {
#       "id": "ワンタンメン",
#       "group": 4
#     },
#     {
#       "id": "チャーシューメン",
#       "group": 7
#     },
#     {
#       "id": "鉄火丼",
#       "group": 10
#     },
#     {
#       "id": "シュウマイ",
#       "group": 13
#     },
#     {
#       "id": "グリーンサラダ",
#       "group": 14
#     },
#     {
#       "id": "甘エビの刺身",
#       "group": 12
#     },
#     {
#       "id": "ハムサンド",
#       "group": 2
#     },
#     {
#       "id": "ハムエッグ",
#       "group": 2
#     },
#     {
#       "id": "ブリの照り焼き",
#       "group": 3
#     },
#     {
#       "id": "サンマの塩焼き",
#       "group": 11
#     },
#     {
#       "id": "冷やし中華",
#       "group": 5
#     },
#     {
#       "id": "ミックスサンド",
#       "group": 2
#     },
#     {
#       "id": "ツナサンド",
#       "group": 2
#     },
#     {
#       "id": "杏仁豆腐",
#       "group": 5
#     },
#     {
#       "id": "ちらし寿司",
#       "group": 3
#     },
#     {
#       "id": "納豆",
#       "group": 5
#     },
#     {
#       "id": "きんぴらごぼう",
#       "group": 11
#     },
#     {
#       "id": "五目そば",
#       "group": 13
#     },
#     {
#       "id": "ジャージャーメン",
#       "group": 1
#     },
#     {
#       "id": "マカロニサラダ",
#       "group": 14
#     },
#     {
#       "id": "ざるそば",
#       "group": 3
#     },
#     {
#       "id": "カツオのたたき",
#       "group": 4
#     },
#     {
#       "id": "力うどん",
#       "group": 9
#     },
#     {
#       "id": "うな丼",
#       "group": 4
#     },
#     {
#       "id": "大根の煮物",
#       "group": 11
#     },
#     {
#       "id": "天丼",
#       "group": 4
#     },
#     {
#       "id": "鮭のムニエル",
#       "group": 3
#     },
#     {
#       "id": "ボンゴレ",
#       "group": 10
#     },
#     {
#       "id": "かつ丼",
#       "group": 4
#     },
#     {
#       "id": "ホイコウロウ",
#       "group": 13
#     },
#     {
#       "id": "冷やっこ",
#       "group": 5
#     },
#     {
#       "id": "麻婆丼",
#       "group": 4
#     },
#     {
#       "id": "イカの天ぷら",
#       "group": 3
#     },
#     {
#       "id": "中華丼",
#       "group": 0
#     },
#     {
#       "id": "大福もち",
#       "group": 6
#     },
#     {
#       "id": "かけそば",
#       "group": 4
#     },
#     {
#       "id": "八宝菜",
#       "group": 0
#     },
#     {
#       "id": "コーヒーゼリー",
#       "group": 6
#     },
#     {
#       "id": "宇治金時（かき氷）",
#       "group": 5
#     },
#     {
#       "id": "ひじきの煮物",
#       "group": 11
#     },
#     {
#       "id": "天ぷらそば",
#       "group": 4
#     },
#     {
#       "id": "野菜の煮物",
#       "group": 11
#     },
#     {
#       "id": "シーフードカレー",
#       "group": 9
#     },
#     {
#       "id": "あんみつ",
#       "group": 5
#     },
#     {
#       "id": "ぜんざい",
#       "group": 5
#     },
#     {
#       "id": "酢豚",
#       "group": 13
#     },
#     {
#       "id": "あじフライ",
#       "group": 8
#     },
#     {
#       "id": "牡蠣フライ",
#       "group": 8
#     },
#     {
#       "id": "ニラレバ炒め",
#       "group": 7
#     }
#   ],
#   "links": [
#     {
#       "source": "鶏のから揚げ",
#       "target": "フライドチキン",
#       "value": 6.424640922383755
#     },
#     {
#       "source": "鶏のから揚げ",
#       "target": "しょうが焼き",
#       "value": 5.772382627055354
#     },
#     {
#       "source": "鶏のから揚げ",
#       "target": "フライドポテト",
#       "value": 5.746088200221281
#     },
#     {
#       "source": "鶏のから揚げ",
#       "target": "肉じゃが",
#       "value": 5.712733020923139
#     },
#     {
#       "source": "鶏のから揚げ",
#       "target": "ハンバーグ",
#       "value": 5.706434480509186
#     },
#     {
#       "source": "アイスクリーム",
#       "target": "シュークリーム",
#       "value": 6.659034954373136
#     },
#     {
#       "source": "アイスクリーム",
#       "target": "コーヒーゼリー",
#       "value": 6.1828573587142195
#     },
#     {
#       "source": "アイスクリーム",
#       "target": "チーズケーキ",
#       "value": 6.1630174395450075
#     },
#     {
#       "source": "アイスクリーム",
#       "target": "チョコレートケーキ",
#       "value": 5.925819249523063
#     },
#     {
#       "source": "アイスクリーム",
#       "target": "プリン",
#       "value": 5.919409904511282
#     },
#     {
#       "source": "フライドポテト",
#       "target": "ポテトサラダ",
#       "value": 7.3072944966167075
#     },
#     {
#       "source": "フライドポテト",
#       "target": "あじフライ",
#       "value": 6.8402323421524
#     },
#     {
#       "source": "フライドポテト",
#       "target": "肉じゃが",
#       "value": 6.346785639186429
#     },
#     {
#       "source": "フライドポテト",
#       "target": "フライドチキン",
#       "value": 6.311564420664166
#     },
#     {
#       "source": "フライドポテト",
#       "target": "コロッケ",
#       "value": 6.159114493037588
#     },
#     {
#       "source": "オムライス",
#       "target": "ドリア",
#       "value": 5.934390231204115
#     },
#     {
#       "source": "オムライス",
#       "target": "塩ラーメン",
#       "value": 5.848434950900127
#     },
#     {
#       "source": "オムライス",
#       "target": "ハンバーグ",
#       "value": 5.55697857588446
#     },
#     {
#       "source": "オムライス",
#       "target": "しょうゆラーメン",
#       "value": 5.541528517441824
#     },
#     {
#       "source": "オムライス",
#       "target": "フライドチキン",
#       "value": 5.531163606192685
#     },
#     {
#       "source": "豚汁",
#       "target": "味噌汁",
#       "value": 7.51715853437144
#     },
#     {
#       "source": "豚汁",
#       "target": "酢豚",
#       "value": 6.78087829039248
#     },
#     {
#       "source": "豚汁",
#       "target": "野菜の煮物",
#       "value": 6.129337602706686
#     },
#     {
#       "source": "豚汁",
#       "target": "豚の角煮",
#       "value": 6.12797987234898
#     },
#     {
#       "source": "豚汁",
#       "target": "肉じゃが",
#       "value": 6.073331445079345
#     },
#     {
#       "source": "餃子",
#       "target": "シュウマイ",
#       "value": 6.949135566620054
#     },
#     {
#       "source": "餃子",
#       "target": "春巻き",
#       "value": 6.369891381155474
#     },
#     {
#       "source": "餃子",
#       "target": "しょうが焼き",
#       "value": 6.272124581226734
#     },
#     {
#       "source": "餃子",
#       "target": "酢豚",
#       "value": 6.1904104846896235
#     },
#     {
#       "source": "餃子",
#       "target": "五目焼きそば",
#       "value": 5.9945500500419495
#     },
#     {
#       "source": "ご飯",
#       "target": "ぜんざい",
#       "value": 5.7026185081848535
#     },
#     {
#       "source": "ご飯",
#       "target": "鍋焼きうどん",
#       "value": 5.48434724647794
#     },
#     {
#       "source": "ご飯",
#       "target": "にぎり寿司",
#       "value": 5.401502269217087
#     },
#     {
#       "source": "ご飯",
#       "target": "野菜の煮物",
#       "value": 5.398672639080316
#     },
#     {
#       "source": "ご飯",
#       "target": "あじフライ",
#       "value": 5.275875854339592
#     },
#     {
#       "source": "ハンバーグ",
#       "target": "ハンバーガ",
#       "value": 6.933983499054249
#     },
#     {
#       "source": "ハンバーグ",
#       "target": "ハムエッグ",
#       "value": 6.419209253492808
#     },
#     {
#       "source": "ハンバーグ",
#       "target": "コロッケ",
#       "value": 6.065042194695608
#     },
#     {
#       "source": "ハンバーグ",
#       "target": "酢豚",
#       "value": 6.035321328693679
#     },
#     {
#       "source": "ハンバーグ",
#       "target": "ハムサンド",
#       "value": 5.969325863509194
#     },
#     {
#       "source": "ローストビーフ",
#       "target": "牛丼",
#       "value": 6.231862587276858
#     },
#     {
#       "source": "ローストビーフ",
#       "target": "ブリの照り焼き",
#       "value": 5.9130596580991455
#     },
#     {
#       "source": "ローストビーフ",
#       "target": "ヒレステーキ",
#       "value": 5.837145511246696
#     },
#     {
#       "source": "ローストビーフ",
#       "target": "ビーフカレー",
#       "value": 5.610176632758503
#     },
#     {
#       "source": "にぎり寿司",
#       "target": "ちらし寿司",
#       "value": 7.260251005509982
#     },
#     {
#       "source": "にぎり寿司",
#       "target": "いくら丼",
#       "value": 6.324609392377949
#     },
#     {
#       "source": "にぎり寿司",
#       "target": "鉄火丼",
#       "value": 6.295049610668649
#     },
#     {
#       "source": "にぎり寿司",
#       "target": "ネギトロ丼",
#       "value": 6.039856399107441
#     },
#     {
#       "source": "にぎり寿司",
#       "target": "マグロの刺身",
#       "value": 5.7742426605595485
#     },
#     {
#       "source": "味噌汁",
#       "target": "味噌ラーメン",
#       "value": 6.101402975911726
#     },
#     {
#       "source": "味噌汁",
#       "target": "野菜の煮物",
#       "value": 5.959304477664691
#     },
#     {
#       "source": "味噌汁",
#       "target": "ロールキャベツ",
#       "value": 5.733507606399364
#     },
#     {
#       "source": "味噌汁",
#       "target": "冷やっこ",
#       "value": 5.592059834644747
#     },
#     {
#       "source": "ビーフシチュー",
#       "target": "チャーシューメン",
#       "value": 6.195018843178523
#     },
#     {
#       "source": "ビーフシチュー",
#       "target": "牛丼",
#       "value": 6.0476822162557315
#     },
#     {
#       "source": "ビーフシチュー",
#       "target": "ビーフカレー",
#       "value": 6.018545315513485
#     },
#     {
#       "source": "ビーフシチュー",
#       "target": "肉じゃが",
#       "value": 6.0072311282874935
#     },
#     {
#       "source": "ビーフシチュー",
#       "target": "チキンカレー",
#       "value": 5.933177362044113
#     },
#     {
#       "source": "サーロインステーキ",
#       "target": "ヒレステーキ",
#       "value": 7.458192048159507
#     },
#     {
#       "source": "サーロインステーキ",
#       "target": "ミートスパゲティ",
#       "value": 5.835852632383043
#     },
#     {
#       "source": "サーロインステーキ",
#       "target": "サンマの塩焼き",
#       "value": 5.58173509652241
#     },
#     {
#       "source": "サーロインステーキ",
#       "target": "牛丼",
#       "value": 5.4983415126673005
#     },
#     {
#       "source": "ハンバーガ",
#       "target": "ハムサンド",
#       "value": 6.560361614994937
#     },
#     {
#       "source": "ハンバーガ",
#       "target": "ホットドック",
#       "value": 5.87501417282267
#     },
#     {
#       "source": "ハンバーガ",
#       "target": "ツナサンド",
#       "value": 5.732891612489599
#     },
#     {
#       "source": "ハンバーガ",
#       "target": "タマゴサンド",
#       "value": 5.730129787352379
#     },
#     {
#       "source": "ネギトロ丼",
#       "target": "鉄火丼",
#       "value": 7.195875296279559
#     },
#     {
#       "source": "ネギトロ丼",
#       "target": "マグロ・トロの刺身",
#       "value": 7.007530538617671
#     },
#     {
#       "source": "ネギトロ丼",
#       "target": "マグロの刺身",
#       "value": 6.490873290261151
#     },
#     {
#       "source": "ネギトロ丼",
#       "target": "うな丼",
#       "value": 6.004554821502444
#     },
#     {
#       "source": "プリン",
#       "target": "モンブラン",
#       "value": 6.358010603524673
#     },
#     {
#       "source": "プリン",
#       "target": "シュークリーム",
#       "value": 5.901360201201333
#     },
#     {
#       "source": "プリン",
#       "target": "ホットケーキ",
#       "value": 5.710775736065399
#     },
#     {
#       "source": "プリン",
#       "target": "チョコレートケーキ",
#       "value": 5.582304981418071
#     },
#     {
#       "source": "海老の天ぷら",
#       "target": "イカの天ぷら",
#       "value": 7.429427309857267
#     },
#     {
#       "source": "海老の天ぷら",
#       "target": "エビフライ",
#       "value": 6.863119509730751
#     },
#     {
#       "source": "海老の天ぷら",
#       "target": "天丼",
#       "value": 6.752444996953615
#     },
#     {
#       "source": "海老の天ぷら",
#       "target": "天ぷらそば",
#       "value": 6.206565880662063
#     },
#     {
#       "source": "海老の天ぷら",
#       "target": "エビチリ",
#       "value": 6.185965794912477
#     },
#     {
#       "source": "肉じゃが",
#       "target": "コロッケ",
#       "value": 6.415658098083704
#     },
#     {
#       "source": "肉じゃが",
#       "target": "しょうが焼き",
#       "value": 6.362345290026992
#     },
#     {
#       "source": "肉じゃが",
#       "target": "ジャージャーメン",
#       "value": 6.3286661376774935
#     },
#     {
#       "source": "肉じゃが",
#       "target": "酢豚",
#       "value": 6.27582213827352
#     },
#     {
#       "source": "フライドチキン",
#       "target": "あじフライ",
#       "value": 6.315850095009575
#     },
#     {
#       "source": "フライドチキン",
#       "target": "牡蠣フライ",
#       "value": 5.895429535237882
#     },
#     {
#       "source": "フライドチキン",
#       "target": "エビフライ",
#       "value": 5.711845465105629
#     },
#     {
#       "source": "ミートスパゲティ",
#       "target": "タラコスパゲティ",
#       "value": 7.786472651814211
#     },
#     {
#       "source": "ミートスパゲティ",
#       "target": "ミックスピザ",
#       "value": 6.269071089625534
#     },
#     {
#       "source": "ミートスパゲティ",
#       "target": "ポテトサラダ",
#       "value": 6.032598278130691
#     },
#     {
#       "source": "しょうが焼き",
#       "target": "野菜炒め",
#       "value": 6.630859104436056
#     },
#     {
#       "source": "しょうが焼き",
#       "target": "五目焼きそば",
#       "value": 6.604860368197086
#     },
#     {
#       "source": "しょうが焼き",
#       "target": "シュウマイ",
#       "value": 6.199568927725742
#     },
#     {
#       "source": "マカロニグラタン",
#       "target": "マカロニサラダ",
#       "value": 6.482406005574455
#     },
#     {
#       "source": "マカロニグラタン",
#       "target": "ラザニア",
#       "value": 6.394432082563029
#     },
#     {
#       "source": "マカロニグラタン",
#       "target": "ドリア",
#       "value": 6.207436222687899
#     },
#     {
#       "source": "マカロニグラタン",
#       "target": "コロッケ",
#       "value": 6.002885875945664
#     },
#     {
#       "source": "シュークリーム",
#       "target": "ホットケーキ",
#       "value": 6.5065732552201645
#     },
#     {
#       "source": "シュークリーム",
#       "target": "モンブラン",
#       "value": 6.381476360258901
#     },
#     {
#       "source": "シュークリーム",
#       "target": "ショートケーキ",
#       "value": 6.199618152072653
#     },
#     {
#       "source": "シュークリーム",
#       "target": "チョコレートケーキ",
#       "value": 6.139123051112241
#     },
#     {
#       "source": "エビフライ",
#       "target": "牡蠣フライ",
#       "value": 6.7574460848785955
#     },
#     {
#       "source": "エビフライ",
#       "target": "あじフライ",
#       "value": 6.717229651652144
#     },
#     {
#       "source": "エビフライ",
#       "target": "エビチリ",
#       "value": 6.276837857453392
#     },
#     {
#       "source": "エビフライ",
#       "target": "甘エビの刺身",
#       "value": 6.00711961865736
#     },
#     {
#       "source": "ドリア",
#       "target": "ラザニア",
#       "value": 6.150494268694894
#     },
#     {
#       "source": "チョコレートケーキ",
#       "target": "チーズケーキ",
#       "value": 7.8011694563177345
#     },
#     {
#       "source": "チョコレートケーキ",
#       "target": "ホットケーキ",
#       "value": 7.006228101651617
#     },
#     {
#       "source": "チョコレートケーキ",
#       "target": "ショートケーキ",
#       "value": 6.879739668981317
#     },
#     {
#       "source": "マグロ・トロの刺身",
#       "target": "マグロの刺身",
#       "value": 8.994221451711407
#     },
#     {
#       "source": "マグロ・トロの刺身",
#       "target": "鉄火丼",
#       "value": 7.13620221391761
#     },
#     {
#       "source": "マグロ・トロの刺身",
#       "target": "甘エビの刺身",
#       "value": 6.439491845442488
#     },
#     {
#       "source": "マグロ・トロの刺身",
#       "target": "カツオのたたき",
#       "value": 5.361137897585941
#     },
#     {
#       "source": "ビビンバ",
#       "target": "鍋焼きうどん",
#       "value": 5.548810182206303
#     },
#     {
#       "source": "ビビンバ",
#       "target": "冷やっこ",
#       "value": 5.269712669057617
#     },
#     {
#       "source": "ビビンバ",
#       "target": "納豆",
#       "value": 5.200954266887604
#     },
#     {
#       "source": "ビビンバ",
#       "target": "豚の角煮",
#       "value": 5.119266626581843
#     },
#     {
#       "source": "ロールキャベツ",
#       "target": "野菜の煮物",
#       "value": 6.0212574576961995
#     },
#     {
#       "source": "ロールキャベツ",
#       "target": "ホイコウロウ",
#       "value": 5.923111863183756
#     },
#     {
#       "source": "ロールキャベツ",
#       "target": "味噌ラーメン",
#       "value": 5.883560321341678
#     },
#     {
#       "source": "ロールキャベツ",
#       "target": "大根の煮物",
#       "value": 5.650088649882901
#     },
#     {
#       "source": "タピオカ",
#       "target": "タラコスパゲティ",
#       "value": 5.556048866265588
#     },
#     {
#       "source": "タピオカ",
#       "target": "ホットケーキ",
#       "value": 4.982357283081979
#     },
#     {
#       "source": "タピオカ",
#       "target": "カツオのたたき",
#       "value": 4.870524750882334
#     },
#     {
#       "source": "味噌ラーメン",
#       "target": "塩ラーメン",
#       "value": 8.389985791250096
#     },
#     {
#       "source": "味噌ラーメン",
#       "target": "しょうゆラーメン",
#       "value": 8.171979934406906
#     },
#     {
#       "source": "味噌ラーメン",
#       "target": "チャーシューメン",
#       "value": 6.934058081803945
#     },
#     {
#       "source": "味噌ラーメン",
#       "target": "ワンタンメン",
#       "value": 6.599700774084791
#     },
#     {
#       "source": "味噌ラーメン",
#       "target": "ニラレバ炒め",
#       "value": 6.333581983442346
#     },
#     {
#       "source": "ミックスピザ",
#       "target": "ミックスサンド",
#       "value": 6.2883986608609135
#     },
#     {
#       "source": "ミックスピザ",
#       "target": "ホットドック",
#       "value": 5.713087458602879
#     },
#     {
#       "source": "ミックスピザ",
#       "target": "ハムサンド",
#       "value": 5.31786076416611
#     },
#     {
#       "source": "チーズケーキ",
#       "target": "ホットケーキ",
#       "value": 6.776548981676535
#     },
#     {
#       "source": "チーズケーキ",
#       "target": "ショートケーキ",
#       "value": 6.289700120032328
#     },
#     {
#       "source": "ショートケーキ",
#       "target": "ホットケーキ",
#       "value": 6.54789847366718
#     },
#     {
#       "source": "ビーフカレー",
#       "target": "シーフードカレー",
#       "value": 8.216059742138757
#     },
#     {
#       "source": "ビーフカレー",
#       "target": "チキンカレー",
#       "value": 8.033597146415625
#     },
#     {
#       "source": "ビーフカレー",
#       "target": "カレーうどん",
#       "value": 6.769452103516392
#     },
#     {
#       "source": "ビーフカレー",
#       "target": "ニラレバ炒め",
#       "value": 6.202813065662025
#     },
#     {
#       "source": "タラコスパゲティ",
#       "target": "カツオのたたき",
#       "value": 6.276997110644547
#     },
#     {
#       "source": "タラコスパゲティ",
#       "target": "ボンゴレ",
#       "value": 5.919304710878892
#     },
#     {
#       "source": "タラコスパゲティ",
#       "target": "ざるそば",
#       "value": 5.804537928871715
#     },
#     {
#       "source": "タラコスパゲティ",
#       "target": "サンマの塩焼き",
#       "value": 5.590820421319603
#     },
#     {
#       "source": "マグロの刺身",
#       "target": "鉄火丼",
#       "value": 7.599298338209479
#     },
#     {
#       "source": "マグロの刺身",
#       "target": "甘エビの刺身",
#       "value": 6.696673908923939
#     },
#     {
#       "source": "しょうゆラーメン",
#       "target": "塩ラーメン",
#       "value": 8.950098466967736
#     },
#     {
#       "source": "しょうゆラーメン",
#       "target": "チャーシューメン",
#       "value": 8.04401181156922
#     },
#     {
#       "source": "しょうゆラーメン",
#       "target": "ワンタンメン",
#       "value": 6.4938950079298134
#     },
#     {
#       "source": "しょうゆラーメン",
#       "target": "ニラレバ炒め",
#       "value": 6.157472455341452
#     },
#     {
#       "source": "リゾット",
#       "target": "ラザニア",
#       "value": 6.054317679015214
#     },
#     {
#       "source": "リゾット",
#       "target": "杏仁豆腐",
#       "value": 5.4303057214667
#     },
#     {
#       "source": "リゾット",
#       "target": "コロッケ",
#       "value": 5.359651196093229
#     },
#     {
#       "source": "ホットケーキ",
#       "target": "たいやき",
#       "value": 6.021424401720152
#     },
#     {
#       "source": "ラザニア",
#       "target": "カルボナーラ",
#       "value": 5.755617816807281
#     },
#     {
#       "source": "カルボナーラ",
#       "target": "ボンゴレ",
#       "value": 5.604877700015684
#     },
#     {
#       "source": "きつねうどん",
#       "target": "力うどん",
#       "value": 7.461556234383442
#     },
#     {
#       "source": "きつねうどん",
#       "target": "カレーうどん",
#       "value": 7.347333257317649
#     },
#     {
#       "source": "きつねうどん",
#       "target": "鍋焼きうどん",
#       "value": 7.114702749029515
#     },
#     {
#       "source": "きつねうどん",
#       "target": "かつ丼",
#       "value": 7.108845080347836
#     },
#     {
#       "source": "きつねうどん",
#       "target": "うな丼",
#       "value": 6.24302738885536
#     },
#     {
#       "source": "鍋焼きうどん",
#       "target": "カレーうどん",
#       "value": 7.228169459434776
#     },
#     {
#       "source": "鍋焼きうどん",
#       "target": "力うどん",
#       "value": 6.68635992086387
#     },
#     {
#       "source": "鍋焼きうどん",
#       "target": "かつ丼",
#       "value": 5.866980568211368
#     },
#     {
#       "source": "鍋焼きうどん",
#       "target": "野菜の煮物",
#       "value": 5.752506644370908
#     },
#     {
#       "source": "春巻き",
#       "target": "シュウマイ",
#       "value": 6.429420605056465
#     },
#     {
#       "source": "春巻き",
#       "target": "酢豚",
#       "value": 6.306143028145681
#     },
#     {
#       "source": "春巻き",
#       "target": "冷やっこ",
#       "value": 6.0221866436963705
#     },
#     {
#       "source": "チンジャオロース",
#       "target": "酢豚",
#       "value": 6.265514104143483
#     },
#     {
#       "source": "チンジャオロース",
#       "target": "五目焼きそば",
#       "value": 5.891435930363843
#     },
#     {
#       "source": "チンジャオロース",
#       "target": "ホイコウロウ",
#       "value": 5.689227864595353
#     },
#     {
#       "source": "チキンカレー",
#       "target": "シーフードカレー",
#       "value": 7.257594344046936
#     },
#     {
#       "source": "チキンカレー",
#       "target": "カレーうどん",
#       "value": 6.8457163924888675
#     },
#     {
#       "source": "チキンカレー",
#       "target": "塩ラーメン",
#       "value": 6.004733461433872
#     },
#     {
#       "source": "エビチリ",
#       "target": "ニラレバ炒め",
#       "value": 5.827212154514372
#     },
#     {
#       "source": "エビチリ",
#       "target": "ブリの照り焼き",
#       "value": 5.7113898561168295
#     },
#     {
#       "source": "冷しそうめん",
#       "target": "冷やっこ",
#       "value": 6.6793698160560675
#     },
#     {
#       "source": "冷しそうめん",
#       "target": "冷やし中華",
#       "value": 6.09373408108654
#     },
#     {
#       "source": "冷しそうめん",
#       "target": "ざるそば",
#       "value": 5.990155101391102
#     },
#     {
#       "source": "冷しそうめん",
#       "target": "かつ丼",
#       "value": 5.848591884739173
#     },
#     {
#       "source": "ポテトサラダ",
#       "target": "マカロニサラダ",
#       "value": 7.217247934647287
#     },
#     {
#       "source": "ポテトサラダ",
#       "target": "シーフードサラダ",
#       "value": 6.364093955895294
#     },
#     {
#       "source": "ポテトサラダ",
#       "target": "グリーンサラダ",
#       "value": 6.238490580501331
#     },
#     {
#       "source": "シーフードサラダ",
#       "target": "グリーンサラダ",
#       "value": 7.2312705994503705
#     },
#     {
#       "source": "シーフードサラダ",
#       "target": "シーフードカレー",
#       "value": 7.026779296683722
#     },
#     {
#       "source": "シーフードサラダ",
#       "target": "マカロニサラダ",
#       "value": 5.948912671391048
#     },
#     {
#       "source": "親子丼",
#       "target": "かつ丼",
#       "value": 7.22483245229943
#     },
#     {
#       "source": "親子丼",
#       "target": "中華丼",
#       "value": 7.0229445898533935
#     },
#     {
#       "source": "親子丼",
#       "target": "牛丼",
#       "value": 6.678489122958247
#     },
#     {
#       "source": "親子丼",
#       "target": "麻婆丼",
#       "value": 6.414604284764321
#     },
#     {
#       "source": "親子丼",
#       "target": "うな丼",
#       "value": 6.138577227088987
#     },
#     {
#       "source": "塩ラーメン",
#       "target": "チャーシューメン",
#       "value": 7.732194214161542
#     },
#     {
#       "source": "塩ラーメン",
#       "target": "ワンタンメン",
#       "value": 6.797925239442612
#     },
#     {
#       "source": "塩ラーメン",
#       "target": "冷やし中華",
#       "value": 6.202294423873252
#     },
#     {
#       "source": "ホットドック",
#       "target": "コロッケ",
#       "value": 5.580575815594086
#     },
#     {
#       "source": "牛丼",
#       "target": "麻婆丼",
#       "value": 6.620540286055915
#     },
#     {
#       "source": "牛丼",
#       "target": "中華丼",
#       "value": 6.566787064277646
#     },
#     {
#       "source": "牛丼",
#       "target": "鉄火丼",
#       "value": 6.482306121910239
#     },
#     {
#       "source": "タマゴサンド",
#       "target": "ツナサンド",
#       "value": 7.6729654509154175
#     },
#     {
#       "source": "タマゴサンド",
#       "target": "ハムサンド",
#       "value": 7.634791113765172
#     },
#     {
#       "source": "タマゴサンド",
#       "target": "ミックスサンド",
#       "value": 7.274536914539825
#     },
#     {
#       "source": "五目焼きそば",
#       "target": "五目そば",
#       "value": 8.769398866288755
#     },
#     {
#       "source": "五目焼きそば",
#       "target": "酢豚",
#       "value": 6.659928028691501
#     },
#     {
#       "source": "五目焼きそば",
#       "target": "中華丼",
#       "value": 6.615412877271258
#     },
#     {
#       "source": "五目焼きそば",
#       "target": "ざるそば",
#       "value": 6.270621984247842
#     },
#     {
#       "source": "豚の角煮",
#       "target": "酢豚",
#       "value": 6.177491041313354
#     },
#     {
#       "source": "豚の角煮",
#       "target": "ニラレバ炒め",
#       "value": 6.12404753662544
#     },
#     {
#       "source": "たいやき",
#       "target": "あじフライ",
#       "value": 6.121451655120741
#     },
#     {
#       "source": "たいやき",
#       "target": "大福もち",
#       "value": 5.969560853810324
#     },
#     {
#       "source": "たいやき",
#       "target": "イカの天ぷら",
#       "value": 5.763090421378325
#     },
#     {
#       "source": "たいやき",
#       "target": "カツオのたたき",
#       "value": 5.736030189855064
#     },
#     {
#       "source": "いくら丼",
#       "target": "中華丼",
#       "value": 6.56172868599006
#     },
#     {
#       "source": "いくら丼",
#       "target": "かつ丼",
#       "value": 6.214554981415066
#     },
#     {
#       "source": "いくら丼",
#       "target": "天丼",
#       "value": 6.105283502100232
#     },
#     {
#       "source": "コロッケ",
#       "target": "あじフライ",
#       "value": 5.898402442957872
#     },
#     {
#       "source": "野菜炒め",
#       "target": "野菜の煮物",
#       "value": 7.211670060576032
#     },
#     {
#       "source": "野菜炒め",
#       "target": "ニラレバ炒め",
#       "value": 6.2929380531353285
#     },
#     {
#       "source": "野菜炒め",
#       "target": "八宝菜",
#       "value": 6.274589624382654
#     },
#     {
#       "source": "モンブラン",
#       "target": "杏仁豆腐",
#       "value": 5.637863303213637
#     },
#     {
#       "source": "モンブラン",
#       "target": "鮭のムニエル",
#       "value": 5.474262033774626
#     },
#     {
#       "source": "モンブラン",
#       "target": "大福もち",
#       "value": 5.468290256548398
#     },
#     {
#       "source": "カレーうどん",
#       "target": "力うどん",
#       "value": 6.675403325665842
#     },
#     {
#       "source": "ワンタンメン",
#       "target": "チャーシューメン",
#       "value": 6.625316596338457
#     },
#     {
#       "source": "ワンタンメン",
#       "target": "ジャージャーメン",
#       "value": 6.482102211541511
#     },
#     {
#       "source": "チャーシューメン",
#       "target": "ジャージャーメン",
#       "value": 6.52241019052716
#     },
#     {
#       "source": "シュウマイ",
#       "target": "酢豚",
#       "value": 6.527554955938025
#     },
#     {
#       "source": "グリーンサラダ",
#       "target": "シーフードカレー",
#       "value": 5.746684217777219
#     },
#     {
#       "source": "グリーンサラダ",
#       "target": "マカロニサラダ",
#       "value": 5.729517652459944
#     },
#     {
#       "source": "甘エビの刺身",
#       "target": "天丼",
#       "value": 5.840854023992654
#     },
#     {
#       "source": "ハムサンド",
#       "target": "ミックスサンド",
#       "value": 7.811676368912983
#     },
#     {
#       "source": "ハムサンド",
#       "target": "ツナサンド",
#       "value": 7.510060402842544
#     },
#     {
#       "source": "ハムサンド",
#       "target": "ハムエッグ",
#       "value": 6.060386621954362
#     },
#     {
#       "source": "ハムエッグ",
#       "target": "あじフライ",
#       "value": 5.477875739288082
#     },
#     {
#       "source": "ブリの照り焼き",
#       "target": "鮭のムニエル",
#       "value": 5.856071865145362
#     },
#     {
#       "source": "ブリの照り焼き",
#       "target": "サンマの塩焼き",
#       "value": 5.599694298653688
#     },
#     {
#       "source": "サンマの塩焼き",
#       "target": "大根の煮物",
#       "value": 5.959175016913207
#     },
#     {
#       "source": "サンマの塩焼き",
#       "target": "野菜の煮物",
#       "value": 5.898338317951256
#     },
#     {
#       "source": "サンマの塩焼き",
#       "target": "カツオのたたき",
#       "value": 5.892123024564052
#     },
#     {
#       "source": "サンマの塩焼き",
#       "target": "ざるそば",
#       "value": 5.887129615636852
#     },
#     {
#       "source": "冷やし中華",
#       "target": "ジャージャーメン",
#       "value": 6.114439912683201
#     },
#     {
#       "source": "冷やし中華",
#       "target": "中華丼",
#       "value": 5.80677371073998
#     },
#     {
#       "source": "ミックスサンド",
#       "target": "ツナサンド",
#       "value": 6.978451680036719
#     },
#     {
#       "source": "ツナサンド",
#       "target": "うな丼",
#       "value": 5.616224780077208
#     },
#     {
#       "source": "杏仁豆腐",
#       "target": "冷やっこ",
#       "value": 6.169311879274252
#     },
#     {
#       "source": "杏仁豆腐",
#       "target": "あんみつ",
#       "value": 6.02834398838791
#     },
#     {
#       "source": "杏仁豆腐",
#       "target": "コーヒーゼリー",
#       "value": 5.781642826222294
#     },
#     {
#       "source": "杏仁豆腐",
#       "target": "麻婆丼",
#       "value": 5.625755775086266
#     },
#     {
#       "source": "ちらし寿司",
#       "target": "シーフードカレー",
#       "value": 5.513451198340688
#     },
#     {
#       "source": "ちらし寿司",
#       "target": "牡蠣フライ",
#       "value": 5.2917850697390385
#     },
#     {
#       "source": "ちらし寿司",
#       "target": "ざるそば",
#       "value": 5.237322609662149
#     },
#     {
#       "source": "納豆",
#       "target": "冷やっこ",
#       "value": 6.470190796722751
#     },
#     {
#       "source": "納豆",
#       "target": "大根の煮物",
#       "value": 6.2040371280764885
#     },
#     {
#       "source": "納豆",
#       "target": "野菜の煮物",
#       "value": 5.963771336315372
#     },
#     {
#       "source": "納豆",
#       "target": "麻婆丼",
#       "value": 5.857287634098109
#     },
#     {
#       "source": "きんぴらごぼう",
#       "target": "野菜の煮物",
#       "value": 6.158963908932503
#     },
#     {
#       "source": "きんぴらごぼう",
#       "target": "八宝菜",
#       "value": 6.025582613864723
#     },
#     {
#       "source": "きんぴらごぼう",
#       "target": "ひじきの煮物",
#       "value": 5.885066197991677
#     },
#     {
#       "source": "五目そば",
#       "target": "ざるそば",
#       "value": 6.010921454080028
#     },
#     {
#       "source": "五目そば",
#       "target": "中華丼",
#       "value": 5.967482889124549
#     },
#     {
#       "source": "五目そば",
#       "target": "酢豚",
#       "value": 5.742985517511219
#     },
#     {
#       "source": "五目そば",
#       "target": "天ぷらそば",
#       "value": 5.726948742264576
#     },
#     {
#       "source": "ジャージャーメン",
#       "target": "酢豚",
#       "value": 6.082058726215912
#     },
#     {
#       "source": "ざるそば",
#       "target": "かけそば",
#       "value": 7.378565227885651
#     },
#     {
#       "source": "ざるそば",
#       "target": "天ぷらそば",
#       "value": 6.905851064886425
#     },
#     {
#       "source": "カツオのたたき",
#       "target": "牡蠣フライ",
#       "value": 5.686019037465973
#     },
#     {
#       "source": "力うどん",
#       "target": "かつ丼",
#       "value": 5.690224782888153
#     },
#     {
#       "source": "力うどん",
#       "target": "ぜんざい",
#       "value": 5.482093227142366
#     },
#     {
#       "source": "うな丼",
#       "target": "かつ丼",
#       "value": 7.080316441706456
#     },
#     {
#       "source": "うな丼",
#       "target": "天丼",
#       "value": 6.413994321932471
#     },
#     {
#       "source": "うな丼",
#       "target": "中華丼",
#       "value": 6.173824187056155
#     },
#     {
#       "source": "大根の煮物",
#       "target": "野菜の煮物",
#       "value": 7.852338239920397
#     },
#     {
#       "source": "大根の煮物",
#       "target": "ひじきの煮物",
#       "value": 5.747039877010072
#     },
#     {
#       "source": "天丼",
#       "target": "かつ丼",
#       "value": 7.277175504799943
#     },
#     {
#       "source": "天丼",
#       "target": "天ぷらそば",
#       "value": 7.149506180033662
#     },
#     {
#       "source": "天丼",
#       "target": "イカの天ぷら",
#       "value": 6.425381251128069
#     },
#     {
#       "source": "天丼",
#       "target": "中華丼",
#       "value": 6.420483503103641
#     },
#     {
#       "source": "かつ丼",
#       "target": "中華丼",
#       "value": 6.563723394002295
#     },
#     {
#       "source": "ホイコウロウ",
#       "target": "八宝菜",
#       "value": 5.9518770911482
#     },
#     {
#       "source": "冷やっこ",
#       "target": "麻婆丼",
#       "value": 5.99860668737657
#     },
#     {
#       "source": "麻婆丼",
#       "target": "中華丼",
#       "value": 6.284721746319949
#     },
#     {
#       "source": "イカの天ぷら",
#       "target": "天ぷらそば",
#       "value": 6.127549368716256
#     },
#     {
#       "source": "イカの天ぷら",
#       "target": "あじフライ",
#       "value": 6.001940869243344
#     },
#     {
#       "source": "中華丼",
#       "target": "八宝菜",
#       "value": 7.000353287997909
#     },
#     {
#       "source": "大福もち",
#       "target": "ぜんざい",
#       "value": 5.645052062326485
#     },
#     {
#       "source": "かけそば",
#       "target": "天ぷらそば",
#       "value": 6.541496680857065
#     },
#     {
#       "source": "八宝菜",
#       "target": "酢豚",
#       "value": 6.201096283502673
#     },
#     {
#       "source": "コーヒーゼリー",
#       "target": "あんみつ",
#       "value": 5.937911645419901
#     },
#     {
#       "source": "宇治金時（かき氷）",
#       "target": "あんみつ",
#       "value": 5.790375027644258
#     },
#     {
#       "source": "宇治金時（かき氷）",
#       "target": "ぜんざい",
#       "value": 5.1966658485963375
#     },
#     {
#       "source": "ひじきの煮物",
#       "target": "野菜の煮物",
#       "value": 7.117710837233382
#     },
#     {
#       "source": "あじフライ",
#       "target": "牡蠣フライ",
#       "value": 6.82833329290725
#     }
#   ]
# }

# %% [markdown]
# こうして作られたJSONファイルはD3.jsの[こちらのCodeSandbox](https://n34r28.csb.app/)を使ってグラフ可視化することが可能です。

# %% [markdown]
# 以下は各ノードの次数（エッジ数）の分布のヒストグラムです。必要に応じて抽出するエッジ数（現在は3）を調整してください。

# %%
import matplotlib.pyplot as plt

# 各ノードのエッジ数をカウント
degrees = collections.defaultdict(int)
for edge in edges:
    degrees[edge['source']] += 1
    degrees[edge['target']] += 1

# エッジ数のリストを抽出
edges_per_node = list(degrees.values())

# ヒストグラムを作成
plt.figure(figsize=(10, 6))
plt.hist(edges_per_node, bins=range(min(edges_per_node), max(edges_per_node) + 2), edgecolor='black')
plt.title('Distribution of Edge Counts per Food Item (Top 3 Similar)')
plt.xlabel('Number of Edges')
plt.ylabel('Number of Food Items')
plt.xticks(range(min(edges_per_node), max(edges_per_node) + 1))
plt.grid(axis='y', alpha=0.75)
plt.show()
